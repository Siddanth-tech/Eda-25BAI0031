# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddanth-tech/Eda-25BAI0031/blob/main/assignment%204.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=np.arange(10,20).reshape(5,2)
df=pd.DataFrame(data,index=['a','b','c','d','e'],columns=['grp1','grp2'])
df
# Out:
#    grp1  grp2
# a    10    11
# b    12    13
# c    14    15
# d    16    17
# e    18    19

# %%
df['grp1']=np.nan
df.loc['b']=np.nan
df.loc['d']=np.arange(1,3)
df['grp1']['a']=67
df
# Out:
# /tmp/ipykernel_3585/3530964106.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['grp1']['a']=67
#    grp1  grp2
# a  67.0  11.0
# b   NaN   NaN
# c   NaN  15.0
# d   1.0   2.0
# e   NaN  19.0

# %%
df.isnull()
# Out:
#     grp1   grp2
# a  False  False
# b   True   True
# c   True  False
# d  False  False
# e   True  False

# %%
df.notnull()
# Out:
#     grp1   grp2
# a   True   True
# b  False  False
# c  False   True
# d   True   True
# e  False   True

# %%
df.isnull().sum()
# Out:
# grp1    3
# grp2    1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(4)

# %%
df.count()
# Out:
# grp1    2
# grp2    4
# dtype: int64

# %%
df.grp1[df.grp1.notnull()]
# Out:
# a    67.0
# d     1.0
# Name: grp1, dtype: float64

# %%
df.grp1.dropna()
# Out:
# a    67.0
# d     1.0
# Name: grp1, dtype: float64

# %%
df.dropna()
# Out:
#    grp1  grp2
# a  67.0  11.0
# d   1.0   2.0

# %% [markdown]
# this drops all rows which has nan values

# %%
df.dropna(how='all')
# Out:
#    grp1  grp2
# a  67.0  11.0
# c   NaN  15.0
# d   1.0   2.0
# e   NaN  19.0

# %% [markdown]
# this drops only rows with all nan

# %%
df.dropna(how='all',axis=1)
# Out:
#    grp1  grp2
# a  67.0  11.0
# b   NaN   NaN
# c   NaN  15.0
# d   1.0   2.0
# e   NaN  19.0

# %% [markdown]
# checks column instead of rows

# %%
df.dropna(thresh=3,axis=1)
# Out:
#    grp2
# a  11.0
# b   NaN
# c  15.0
# d   2.0
# e  19.0

# %% [markdown]
# this checks the minm no. of nan to be, then only drops

# %%
ar=np.array([10,20,np.nan,30])
ar
# Out:
# array([10., 20., nan, 30.])

# %%
ser1=pd.Series(ar)
ser1
# Out:
# 0    10.0
# 1    20.0
# 2     NaN
# 3    30.0
# dtype: float64

# %%
ar.mean()
# Out:
# np.float64(nan)

# %%
ser1.mean()
# Out:
# np.float64(20.0)

# %%
ser2=df.grp2

# %%
ser2.sum()
# Out:
# np.float64(47.0)

# %%
ser2.cumsum()#cumulative
# Out:
# a    11.0
# b     NaN
# c    26.0
# d    28.0
# e    47.0
# Name: grp2, dtype: float64

# %%
filledDf=df.fillna(0)
filledDf
# Out:
#    grp1  grp2
# a  67.0  11.0
# b   0.0   0.0
# c   0.0  15.0
# d   1.0   2.0
# e   0.0  19.0

# %%
filledDf.mean()
# Out:
# grp1    13.6
# grp2     9.4
# dtype: float64

# %%
df.grp1.fillna(method='ffill')
# Out:
# /tmp/ipykernel_3585/1850045838.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.grp1.fillna(method='ffill')
# a    67.0
# b    67.0
# c    67.0
# d     1.0
# e     1.0
# Name: grp1, dtype: float64

# %% [markdown]
# this copies value of previous value and paste onto nan

# %%
df.grp1.fillna(method='bfill')
# Out:
# /tmp/ipykernel_3585/896691082.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.grp1.fillna(method='bfill')
# a    67.0
# b     1.0
# c     1.0
# d     1.0
# e     NaN
# Name: grp1, dtype: float64
